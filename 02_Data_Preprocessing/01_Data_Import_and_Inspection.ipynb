# %% [markdown]
# <a href="https://colab.research.google.com/github/KrushnaTaur/ML-Practice/blob/main/02_Data_Preprocessing/01_Data_Import_and_Inspection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/ML Practical')
os.listdir()
# Out:
# ['Student_Dropout_Dataset.csv',
#  'ML-Experiment1.pdf',
#  'ML-Experiment2.pdf',
#  'DataDict-Student_Dropout_Dataset.xlsx',
#  'ML-Experiment3&4.ipynb',
#  'Student_Dataset_Cleaned.csv',
#  'ML-Experiment7.ipynb',
#  'ML-Experiment8.ipynb',
#  'ML-Experiment6.ipynb']

# %% [markdown]
# # 2. Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # 3. Load Dataset

# %%
df = pd.read_csv('Student_Dataset_Cleaned.csv')

# %%
# View first 5 rows
df.head()
# Out:
#    Marital_status  Daytime_evening_attendance_  Previous_qualification  \
# 0        0.693147                   713.434901                0.693147
# 1        0.693147                   713.434901                0.693147
# 2        0.693147                   713.434901                0.693147
# 3        0.693147                   713.434901                0.693147
# 4        1.098612                     0.000000                0.693147
#
#    Previous_qualification_grade_  Mother_s_qualification  \
# 0                          122.0                      19
# 1                          160.0                       1
# 2                          122.0                      37
# 3                          122.0                      38
# 4                          100.0                      37
#
#    Father_s_qualification  Mother_s_occupation  Father_s_occupation  \
# 0                      12             1.459736             1.829314
# ...

# %%
# View last 5 rows
df.tail()
# Out:
#       Marital_status  Daytime_evening_attendance_  Previous_qualification  \
# 4419        0.693147                   713.434901                0.693147
# 4420        0.693147                   713.434901                0.693147
# 4421        0.693147                   713.434901                0.693147
# 4422        0.693147                   713.434901                0.693147
# 4423        0.693147                   713.434901                0.693147
#
#       Previous_qualification_grade_  Mother_s_qualification  \
# 4419                          125.0                       1
# 4420                          120.0                       1
# 4421                          154.0                      37
# 4422                          180.0                      37
# 4423                          152.0                      38
#
#       Father_s_qualification  Mother_s_occupation  Father_s_occupation  \
# 4419                       1             1.459736             1.367593
# ...

# %%
# Check shape (rows, columns)
print("Shape:", df.shape)
# Out:
# Shape: (4424, 33)

# %%
# Check column names
print("Columns:", df.columns.tolist())
# Out:
# Columns: ['Marital_status', 'Daytime_evening_attendance_', 'Previous_qualification', 'Previous_qualification_grade_', 'Mother_s_qualification', 'Father_s_qualification', 'Mother_s_occupation', 'Father_s_occupation', 'Admission_grade', 'Displaced', 'Educational_special_needs', 'Debtor', 'Tuition_fees_up_to_date', 'Gender', 'Scholarship_holder', 'Age_at_enrollment', 'International', 'Curricular_units_1st_sem_credited_', 'Curricular_units_1st_sem_enrolled_', 'Curricular_units_1st_sem_evaluations_', 'Curricular_units_1st_sem_approved_', 'Curricular_units_1st_sem_without_evaluations_', 'Curricular_units_2nd_sem_credited_', 'Curricular_units_2nd_sem_enrolled_', 'Curricular_units_2nd_sem_evaluations_', 'Curricular_units_2nd_sem_approved_', 'Curricular_units_2nd_sem_without_evaluations_', 'Unemployment_rate', 'Inflation_rate', 'GDP', 'Target', 'Overall_Performance', 'Financial_Stability_Score']

# %%
# Check data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 33 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Marital_status                                 4424 non-null   float64
#  1   Daytime_evening_attendance_                    4424 non-null   float64
#  2   Previous_qualification                         4424 non-null   float64
#  3   Previous_qualification_grade_                  4424 non-null   float64
#  4   Mother_s_qualification                         4424 non-null   int64
#  5   Father_s_qualification                         4424 non-null   int64
#  6   Mother_s_occupation                            4424 non-null   float64
#  7   Father_s_occupation                            4424 non-null   float64
#  8   Admission_grade                                4424 non-null   float64
# ...

# %%
# Summary statistics for numeric columns
df.describe()
# Out:
#        Marital_status  Daytime_evening_attendance_  Previous_qualification  \
# count     4424.000000                  4424.000000             4424.000000
# mean         0.755265                   635.544065                1.041193
# std          0.192061                   222.517978                0.879222
# min          0.693147                     0.000000                0.693147
# 25%          0.693147                   713.434901                0.693147
# 50%          0.693147                   713.434901                0.693147
# 75%          0.693147                   713.434901                0.693147
# max          1.945910                   713.434901                3.784190
#
#        Previous_qualification_grade_  Mother_s_qualification  \
# count                    4424.000000             4424.000000
# mean                      132.613314               19.561935
# std                        13.188332               15.603186
# ...

# %% [markdown]
# # 4. Check for Missing Values

# %%
print("Missing values per column:\n", df.isnull().sum())
# Out:
# Missing values per column:
#  Marital_status                                   0
# Daytime_evening_attendance_                      0
# Previous_qualification                           0
# Previous_qualification_grade_                    0
# Mother_s_qualification                           0
# Father_s_qualification                           0
# Mother_s_occupation                              0
# Father_s_occupation                              0
# Admission_grade                                  0
# Displaced                                        0
# Educational_special_needs                        0
# Debtor                                           0
# Tuition_fees_up_to_date                          0
# Gender                                           0
# Scholarship_holder                               0
# Age_at_enrollment                                0
# International                                    0
# Curricular_units_1st_sem_credited_               0
# ...

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nMissing values per column:\n", df.isnull().sum())
# Out:
# Shape: (4424, 33)
#
# Columns: ['Marital_status', 'Daytime_evening_attendance_', 'Previous_qualification', 'Previous_qualification_grade_', 'Mother_s_qualification', 'Father_s_qualification', 'Mother_s_occupation', 'Father_s_occupation', 'Admission_grade', 'Displaced', 'Educational_special_needs', 'Debtor', 'Tuition_fees_up_to_date', 'Gender', 'Scholarship_holder', 'Age_at_enrollment', 'International', 'Curricular_units_1st_sem_credited_', 'Curricular_units_1st_sem_enrolled_', 'Curricular_units_1st_sem_evaluations_', 'Curricular_units_1st_sem_approved_', 'Curricular_units_1st_sem_without_evaluations_', 'Curricular_units_2nd_sem_credited_', 'Curricular_units_2nd_sem_enrolled_', 'Curricular_units_2nd_sem_evaluations_', 'Curricular_units_2nd_sem_approved_', 'Curricular_units_2nd_sem_without_evaluations_', 'Unemployment_rate', 'Inflation_rate', 'GDP', 'Target', 'Overall_Performance', 'Financial_Stability_Score']
#
# Missing values per column:
# ...
